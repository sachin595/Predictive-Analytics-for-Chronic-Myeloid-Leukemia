# %%
import pandas as pd
import numpy as np
import joblib
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
# Load the dataset
data = pd.read_excel("C:/Users/sachi/Downloads/Johns_Hopkins/ONCO_datasets/LL CDC data sets/Leukemia/CML_DATA.xlsx")

# %%
# Define the mappings
sex_mapping = {'Male': 0, 'Female': 1}
ethnicity_mapping = {'Hispanic': 1, 'Non-Hispanic': 0}
race_mapping = {'White': 1, 'Black or African American': 0, 'Asian or Pacific Islander': 2}

# %%
# Replace the values using the mappings
data['Sex'] = data['Sex'].replace(sex_mapping)
data['Ethnicity'] = data['Ethnicity'].replace(ethnicity_mapping)
data['Race'] = data['Race'].replace(race_mapping)

# Define the mapping function for AgeGroup
def map_age_group(age_group):
    if age_group == '1-4 years':
        return 0
    elif age_group == '5-9 years':
        return 1
    elif age_group == '10-14 years':
        return 2
    elif age_group == '15-19 years':
        return 3
    elif age_group == '20-24 years':
        return 4
    elif age_group == '25-29 years':
        return 5
    elif age_group == '30-34 years':
        return 6
    elif age_group == '35-39 years':
        return 7
    elif age_group == '40-44 years':
        return 8
    elif age_group == '45-49 years':
        return 9
    elif age_group == '50-54 years':
        return 10
    elif age_group == '55-59 years':
        return 11
    elif age_group == '60-64 years':
        return 12
    elif age_group == '65-69 years':
        return 13
    elif age_group == '70-74 years':
        return 14
    elif age_group == '75-79 years':
        return 15
    elif age_group == '80-84 years':
        return 16
    elif age_group == '85+ years':
        return 17
    else:
        return 18

# Apply the mapping function to the AgeGroup column
data['AgeGroup'] = data['AgeGroup'].apply(map_age_group)

# %%
data.head(50)
# Out:
#     Sex  Year  AgeGroup  Ethnicity  Race  Deaths  Population  Crude Rate  \
# 0     1  2000        18          0     0      16      598720         2.7
# 1     0  2000         6          0     1      19     6806492         0.3
# 2     1  1999         7          0     1      19     8063922         0.2
# 3     1  2000         7          0     1      17     7876392         0.2
# 4     0  1999         7          0     1      37     8092269         0.5
# 5     0  2001         7          0     1      24     7631303         0.3
# 6     1  1999         8          0     1      25     8131895         0.3
# 7     1  2000         8          0     1      19     8173725         0.2
# 8     1  2001         8          0     1      22     8218541         0.3
# 9     0  1999         8          0     1      19     8116052         0.2
# 10    0  2000         8          0     1      25     8157340         0.3
# 11    0  2001         8          0     1      17     8200772         0.2
# 12    0  2002         8          0     1      25     8145366         0.3
# 13    0  2003         8          0     1      23     8047754         0.3
# 14    1  1999         9          0     1      29     7453748         0.4
# 15    1  2000         9          0     1      28     7610259         0.4
# 16    1  2001         9          0     1      23     7731581         0.3
# 17    1  2002         9          0     1      23     7877393         0.3
# 18    0  1999         9          0     1      41     7367292         0.6
# 19    0  2000         9          0     1      35     7526850         0.5
# 20    0  2001         9          0     1      40     7650934         0.5
# 21    0  2003         9          0     1      23     7903008         0.3
# 22    0  2004         9          0     1      20     7963573         0.3
# 23    0  2005         9          0     1      18     8010767         0.2
# 24    0  2007         9          0     1      21     8009745         0.3
# 25    0  2008         9          0     1      18     7922300         0.2
# 26    0  2009         9          0     1      17     7842499         0.2
# 27    1  1999        10          0     1      37     6654988         0.6
# 28    1  2000        10          0     1      41     6934457         0.6
# 29    1  2001        10          0     1      28     7247085         0.4
# 30    1  2002        10          0     1      23     7177101         0.3
# 31    1  2008        10          0     1      16     7933691         0.2
# 32    0  1999        10          0     1      49     6512010         0.8
# 33    0  2000        10          0     1      47     6794908         0.7
# 34    0  2001        10          0     1      43     7097936         0.6
# 35    0  2002        10          0     1      35     7029627         0.5
# 36    0  2003        10          0     1      27     7103502         0.4
# 37    0  2004        10          0     1      24     7226847         0.3
# 38    0  2005        10          0     1      18     7371529         0.2
# 39    0  2006        10          0     1      23     7501275         0.3
# 40    0  2007        10          0     1      24     7646011         0.3
# 41    0  2008        10          0     1      19     7768660         0.2
# 42    0  2009        10          0     1      21     7835991         0.3
# 43    0  2010        10          0     1      17     7888767         0.2
# 44    0  2011        10          0     1      20     7914063         0.3
# 45    0  2012        10          0     1      24     7848496         0.3
# 46    0  2013        10          0     1      18     7755678         0.2
# 47    0  2014        10          0     1      20     7660825         0.3
# 48    0  2017        10          0     1      18     6976356         0.3
# 49    0  2019        10          0     1      19     6531954         0.3
#
#     Survival Rate scaled  Survival Rate
# 0               0.680924       0.999973
# 1               0.989992       0.999997
# 2               0.995613       0.999998
# 3               0.998168       0.999998
# 4               0.966994       0.999995
# 5               0.985427       0.999997
# 6               0.986339       0.999997
# 7               0.996022       0.999998
# 8               0.991471       0.999997
# 9               0.995808       0.999998
# 10              0.986463       0.999997
# 11              0.999270       0.999998
# 12              0.986404       0.999997
# 13              0.989133       0.999997
# 14              0.975796       0.999996
# 15              0.978526       0.999996
# 16              0.987624       0.999997
# 17              0.988335       0.999997
# 18              0.954171       0.999994
# 19              0.965990       0.999995
# 20              0.958524       0.999995
# 21              0.988457       0.999997
# 22              0.993608       0.999997
# 23              0.997023       0.999998
# 24              0.992183       0.999997
# 25              0.996699       0.999998
# 26              0.998047       0.999998
# 27              0.954241       0.999994
# 28              0.949685       0.999994
# 29              0.976145       0.999996
# 30              0.984656       0.999997
# 31              0.999997       0.999998
# 32              0.928867       0.999992
# 33              0.936714       0.999993
# 34              0.947805       0.999994
# 35              0.961742       0.999995
# 36              0.976955       0.999996
# 37              0.983154       0.999997
# 38              0.994507       0.999998
# 39              0.986444       0.999997
# 40              0.985505       0.999997
# 41              0.994457       0.999998
# 42              0.991432       0.999997
# 43              0.998212       0.999998
# 44              0.993405       0.999997
# 45              0.986551       0.999997
# 46              0.996069       0.999998
# 47              0.992326       0.999997
# 48              0.992721       0.999997
# 49              0.988477       0.999997

# %%
# Define features and target variables
features = ['Sex', 'Year', 'AgeGroup', 'Ethnicity', 'Race']
target = 'Crude Rate'

# %%
data.head()
# Out:
#    Sex  Year  AgeGroup  Ethnicity  Race  Deaths  Population  Crude Rate  \
# 0    1  2000        18          0     0      16      598720         2.7
# 1    0  2000         6          0     1      19     6806492         0.3
# 2    1  1999         7          0     1      19     8063922         0.2
# 3    1  2000         7          0     1      17     7876392         0.2
# 4    0  1999         7          0     1      37     8092269         0.5
#
#    Survival Rate scaled  Survival Rate
# 0              0.680924       0.999973
# 1              0.989992       0.999997
# 2              0.995613       0.999998
# 3              0.998168       0.999998
# 4              0.966994       0.999995

# %%
# Normalize the features and target
scaler_features = MinMaxScaler()
scaler_target = MinMaxScaler()


data[features] = scaler_features.fit_transform(data[features])
joblib.dump(scaler_features, 'CMLscalerX.joblib')
data[[target]] = scaler_target.fit_transform(data[[target]])
joblib.dump(scaler_target, 'CMLscalerY.joblib')
# Out:
# ['CMLscalerY.joblib']

# %%
# Access the 'Survival Rate' column
survival_rate_column = data['Survival Rate'].values

# Reshape the data to fit the scaler's requirements (if it's a single feature)
survival_rate_column = survival_rate_column.reshape(-1, 1)

# Initialize the MinMaxScaler
scaler_survivalrate = MinMaxScaler()

# Fit and transform the data
ss_rate_scaled = scaler_survivalrate.fit_transform(survival_rate_column)
joblib.dump(scaler_survivalrate, 'CMLscalerT.joblib')
# Out:
# ['CMLscalerT.joblib']

# %%
# Split the data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# %%
# Prepare the data for LSTM
def create_dataset(data, features, target, seq_length=1):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[features].iloc[i:i+seq_length].values)
        y.append(data[target].iloc[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 20
X_train, y_train = create_dataset(train_data, features, target, seq_length)
X_test, y_test = create_dataset(test_data, features, target, seq_length)

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(seq_length, len(features))))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)

# Save the model
joblib.dump(model, 'CMLmodel.joblib')

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 172ms/step - loss: 0.0262 - val_loss: 0.0901
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0122 - val_loss: 0.0446
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0065 - val_loss: 0.0477
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0065 - val_loss: 0.0612
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0056 - val_loss: 0.0391
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0063 - val_loss: 0.0483
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0052 - val_loss: 0.0497
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0043 - val_loss: 0.0480
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0048 - val_loss: 0.0451
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042 - val_loss: 0.0521
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0046 - val_loss: 0.0475
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0038 - val_loss: 0.0445
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - val_loss: 0.0509
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - val_loss: 0.0469
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0036 - val_loss: 0.0427
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - val_loss: 0.0434
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0036 - val_loss: 0.0400
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - val_loss: 0.0365
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0042 - val_loss: 0.0425
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0409
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036 - val_loss: 0.0391
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - val_loss: 0.0458
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0026 - val_loss: 0.0261
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0040 - val_loss: 0.0448
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0027 - val_loss: 0.0413
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0027 - val_loss: 0.0323
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0029 - val_loss: 0.0276
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0046 - val_loss: 0.0541
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0046 - val_loss: 0.0429
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0043 - val_loss: 0.0339
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - val_loss: 0.0507
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0026 - val_loss: 0.0298
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035 - val_loss: 0.0343
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - val_loss: 0.0368
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0026 - val_loss: 0.0324
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0027 - val_loss: 0.0343
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021 - val_loss: 0.0253
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023 - val_loss: 0.0343
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - val_loss: 0.0405
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - val_loss: 0.0313
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 0.0377
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - val_loss: 0.0330
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0023 - val_loss: 0.0277
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0017 - val_loss: 0.0348
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 0.0302
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0020 - val_loss: 0.0271
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - val_loss: 0.0290
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - val_loss: 0.0277
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0016 - val_loss: 0.0308
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018 - val_loss: 0.0207
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0281
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0015 - val_loss: 0.0234
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0020 - val_loss: 0.0290
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - val_loss: 0.0265
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 0.0494
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - val_loss: 0.0388
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0326
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 0.0379
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - val_loss: 0.0261
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - val_loss: 0.0196
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.8804e-04 - val_loss: 0.0227
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.6302e-04 - val_loss: 0.0326
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0018 - val_loss: 0.0288
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020 - val_loss: 0.0393
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.7065e-04 - val_loss: 0.0270
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.0604e-04 - val_loss: 0.0290
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.5822e-04 - val_loss: 0.0230
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.6809e-04 - val_loss: 0.0229
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1841e-04 - val_loss: 0.0269
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.3702e-04 - val_loss: 0.0225
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.3030e-04 - val_loss: 0.0264
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2172e-04 - val_loss: 0.0273
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.1821e-04 - val_loss: 0.0268
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0023 - val_loss: 0.0338
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - val_loss: 0.0459
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019 - val_loss: 0.0385
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0019 - val_loss: 0.0268
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - val_loss: 0.0375
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0012 - val_loss: 0.0299
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0015 - val_loss: 0.0317
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0012 - val_loss: 0.0271
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0011 - val_loss: 0.0268
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 9.1527e-04 - val_loss: 0.0225
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 0.0249
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.4464e-04 - val_loss: 0.0248
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.9718e-04 - val_loss: 0.0240
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.8549e-04 - val_loss: 0.0216
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.1390e-04 - val_loss: 0.0286
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.8078e-04 - val_loss: 0.0257
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.7324e-04 - val_loss: 0.0217
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0010 - val_loss: 0.0264
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 0.0291
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 0.0245
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.3349e-04 - val_loss: 0.0291
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.3581e-04 - val_loss: 0.0250
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.5695e-04 - val_loss: 0.0258
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.4307e-04 - val_loss: 0.0272
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.0748e-04 - val_loss: 0.0246
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.9439e-04 - val_loss: 0.0266
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.6644e-04 - val_loss: 0.0281
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.7236e-04 - val_loss: 0.0232
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.8920e-04 - val_loss: 0.0297
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0309e-04 - val_loss: 0.0234
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.1712e-04 - val_loss: 0.0292
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5319e-04 - val_loss: 0.0227
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.6092e-04 - val_loss: 0.0296
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.5702e-04 - val_loss: 0.0227
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# Inverse transform the predictions and actual values
train_predict = scaler_target.inverse_transform(train_predict)
test_predict = scaler_target.inverse_transform(test_predict)
y_train = scaler_target.inverse_transform(y_train.reshape(-1, 1))
y_test = scaler_target.inverse_transform(y_test.reshape(-1, 1))

# %%
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(range(len(y_train)), y_train, label='Training Actual')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label='Testing Actual')
plt.plot(range(len(y_train)), train_predict, label='Training Predictions')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), test_predict, label='Testing Predictions')
plt.xlabel('Sample Count')
plt.ylabel('Crude Rate')
plt.legend()
plt.title('Actual vs Predicted Crude Rates')
plt.show()

# %%
# Function to predict future crude rate based on user input
def predict_future_crude_rate(model, user_input, scaler_features, scaler_target, seq_length=3):
    # Normalize user input
    user_input = scaler_features.transform([user_input])
    user_input = np.array([user_input for _ in range(seq_length)]).reshape(1, seq_length, -1)
    
    # Make prediction
    prediction = model.predict(user_input)
    prediction = scaler_target.inverse_transform(prediction)
    
    return prediction[0][0]

# %%
# Example usage: Predict future crude rate for a given user input
user_input = [1, 2008, 1, 0, 1]  # Replace with actual input
predicted_crude_rate = predict_future_crude_rate(model, user_input, scaler_features, scaler_target)
print(f"Predicted Crude Rate: {predicted_crude_rate}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# Predicted Crude Rate: 0.4705542325973511
